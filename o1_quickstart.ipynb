# %% [markdown]
# ## Install OpenAI SDK

# %%
# pip install openai

# %% [markdown]
# ## Basic API call syntex

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model = "gpt-5.2",
    input = "Write one sentence about living a happy life."
)

print(response.output_text)
# Out:
# A happy life comes from nurturing meaningful relationships, practicing gratitude, and aligning your daily choices with what matters most to you.

# %%
### Input to API can be
